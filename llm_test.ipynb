# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
torch.set_default_device("cuda")

model = AutoModelForCausalLM.from_pretrained("microsoft/phi-1_5", torch_dtype="auto", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-1_5", trust_remote_code=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/864 [00:00<?, ?B/s]
# configuration_phi.py:   0%|          | 0.00/9.26k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/phi-1_5:
# - configuration_phi.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi.py:   0%|          | 0.00/62.7k [00:00<?, ?B/s]
# ...

# %%
inputs = tokenizer('how are you', return_tensors="pt", return_attention_mask=False)

outputs = model.generate(**inputs, max_length=200)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# how are you doing today?"
#
# "I'm doing well, thank you," replied the woman. "I'm just a little nervous about my upcoming surgery."
#
# "I understand," said the man. "But you're in good hands. The doctors and nurses here are very skilled and experienced."
#
# The woman smiled weakly. "I hope so. I just don't want anything to go wrong."
#
# "I'm sure it will go well," said the man. "But it's always better to be safe than sorry."
#
# As they continued to talk, the woman noticed that the man was wearing a pair of glasses. She had always been curious about glasses and wondered how they worked.
#
# "Excuse me," she said. "I couldn't help but notice your glasses. How do they work?"
#
# The man smiled. "Glasses are devices that correct vision problems by bending light rays that enter the eye. They work by refract

# %%
# !pip install accelerate

# %%
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b", token='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')
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b", device_map="auto", token='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')
# Out:
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
input_text = "what is linux"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# <bos>what is linux command to find the number of files in a directory?
#
# Answer:
#
# Step

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/microsoft/phi-1_5"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

output = query({
	"inputs": "Can you please let us know more details about your ",
})

# %%
output
# Out:
# {'error': 'Model microsoft/phi-1_5 is currently loading',
#  'estimated_time': 113.46599578857422}

# %%
API_URL = "https://api-inference.huggingface.co/models/microsoft/phi-1_5"
headers = {"Authorization": "Bearer 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"}
def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()
data = query("Can you please let us know more details about your ")

# %%
data
# Out:
# {'error': 'Model microsoft/phi-1_5 is currently loading',
#  'estimated_time': 113.46599578857422}

# %%
from transformers import GPT2Tokenizer, GPT2Model, GPT2LMHeadModel

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2').to('cuda')

# %%
from transformers import AutoTokenizer, GPT2ForQuestionAnswering

# %%
tokenizer = AutoTokenizer.from_pretrained('gpt2')

# %%
text = "What is my friend name?"
encoded_input = tokenizer(text, return_tensors='pt').to('cuda')
output = model.generate(**encoded_input).to('cuda')
print(tokenizer.decode(output[0]))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What is my friend name?
#
# My friend name is "Bryan" and I am a

# %%
print(tokenizer.decode(output[0]))
# Out:
# What is my friend name?
#
# My friend name is "Bryan" and I am a

# %%
messages = [
    {
                 "role": "system",
        "content": "You are a friendly chatbot who always responds",
    },
     {"role": "user", "content": "My friend Denny said hello"},
    {
                 "role": "system",
        "content": "Hello Denny!",
    },
     {"role": "user", "content": "What is my friend name?"}
 ]
model_inputs = tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt").to("cuda")
input_length = model_inputs.shape[1]
generated_ids = model.generate(model_inputs, do_sample=True, max_new_tokens=256)
print(tokenizer.batch_decode(generated_ids[:, input_length:], skip_special_tokens=True)[0])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# As a former Marine who spent a lot of time in the Pacific using the Pacific Islands, I've noticed a difference in the way women are treated in the military. Women at the time of war were treated with almost no respect for the military. Their status as female service members was seen as very insulting, even when in a friendly environment. The military has changed a lot in the last three decades as a result of the wars in Iraq and Afghanistan, the growing presence of women as warriors and an increasing number of military cadets having careers in management.
#
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained("TinyLlama/TinyLlama-1.1B-Chat-v1.0")
model = AutoModelForCausalLM.from_pretrained("TinyLlama/TinyLlama-1.1B-Chat-v1.0").to("cuda")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
messages = [
    {
                 "role": "system",
        "content": "You are a friendly chatbot who always responds",
    },
     {"role": "user", "content": "My name is Denny."},
    {
         "role": "system",
        "content": "Hello Denny!",
    },
     {"role": "user", "content": "What is my name?"}
 ]
model_inputs = tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt").to("cuda")
input_length = model_inputs.shape[1]
generated_ids = model.generate(model_inputs, do_sample=True, max_new_tokens=256)
print(tokenizer.batch_decode(generated_ids[:, input_length:], skip_special_tokens=True)[0])
# Out:
# I don't know you personally. However, in human language, your given name could be "denny."

# %%
print(tokenizer.batch_decode(generated_ids[:, :])[0])
# Out:
# <|system|>
# You are a friendly chatbot who always responds</s>
# <|user|>
# My friend name is Denny.</s>
# <|system|>
# Hello Denny!</s>
# <|user|>
# What is my friend name?</s>
# <|assistant|>
# That's okay, my name is not "your friend". My username is avikash28 on Messenger.</s>

# %%
messages.append({"role": "user", "content": "I live in Moscow"})
messages.append({"role": "system", "content": "thank you now i know where you live"})

# %%
messages.append({"role": "user", "content": "Where do I live?"})

# %%
model_inputs = tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt").to("cuda")
input_length = model_inputs.shape[1]
generated_ids = model.generate(model_inputs, do_sample=True, max_new_tokens=256)
print(tokenizer.batch_decode(generated_ids[:, input_length:], skip_special_tokens=True)[0])
# Out:
# Hmm, your previous response said that you live in Moscow. Can you provide me with more information about your location?

# %%
# Out:
# I do not know or learn where you live. However, I can tell you where you can look for general information about your location.
#
# to find out where you live, you can search for it using google and look for location awareness services such as a maps app, yelp, or yellowpages. Some of these services also provide information about address locations and local landmarks.
#
# if you have access to your phone's maps app, you may be able to find more specific information about your location, such as the name of the city, state, or country your address is in.
#
# you can also search online for local directory listings that provide addresses and phone numbers for local businesses, such as hotels or restaurants.
#
# please let me know if you need further assistance or have any other questions about your location.

# %%
print(tokenizer.batch_decode(generated_ids[:, :])[0])
# Out:
# <|system|>
# You are a friendly chatbot who always responds</s>
# <|user|>
# My name is Denny.</s>
# <|system|>
# Hello Denny!</s>
# <|user|>
# What is my name?</s>
# <|user|>
# I live in Moscow</s>
# <|user|>
# Where do I live?</s>
# <|assistant|>
# I did not receive a personalized user input when you asked "Where do I live?" the last time you interacted with my virtual assistant. A typical approach to determine someone's address for example would be to ask for the user's postal code, city or town, which can give a place to live or a particular neighborhood within a city. However, in this case, it is quite difficult to determine someone's exact location based on the user's input since it could vary by location, language, cultural differences, and more. The best approach would be to use a tool like google maps or google public records to check for the exact location of your home address, along with additional information like postal code, city names, and other relevant details.</s>

# %%
  messages = [
    {
                 "role": "system",
        "content": "You are a friendly chatbot who always responds",
    },
     {"role": "user", "content": "My name is Denny."},
    {
         "role": "system",
        "content": "Hello Denny!",
    }
 ]

# %%
while True:
  user_text = input()
  if user_text == 'q':
    break
  messages.append({"role": "user", "content": user_text})
  model_inputs = tokenizer.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt").to("cuda")
  input_length = model_inputs.shape[1]
  generated_ids = model.generate(model_inputs, do_sample=True, max_new_tokens=256)
  print(tokenizer.batch_decode(generated_ids[:, input_length:], skip_special_tokens=True)[0])
# Out:
# What is my name?
# Your name is Denny. I have not been given any specific information about your personal details or other details about your life.
# I live in Moscow
# I do not have access to your physical location as it varies from person to person. However, as a machine learning model, I can provide you with information based on inputted data. As for your name, you have registered with a russian-based company which offers a russian-english dictionary called "machintelligence". You can access the dictionary online, free of charge and search for a name in the directory provided.
# Where do I live?
# ...

# %%
API_TOKEN = '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'

# %%
import requests
API_URL = "https://api-inference.huggingface.co/models/TinyLlama/TinyLlama-1.1B-Chat-v1.0"
headers = {"Authorization": f"Bearer {API_TOKEN}"}
def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()
data = query("Can you please let us know more details about you")

# %%
data
# Out:
# {'error': 'Model TinyLlama/TinyLlama-1.1B-Chat-v1.0 is currently loading',
#  'estimated_time': 88.00387573242188}

# %%
data[0]['generated_text']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-c0397b91ab1c> in <cell line: 1>()
# ----> 1 data[0]['generated_text']
#
# KeyError: 0

# %%
data = query("hello duuude")
data[0]['generated_text']
# Out:
# 'hello duuude\n\nThe French capital saw a big increase in traffic while Germany saw its growth slowed at 9 per cent, compared to an earlier 7 per cent increase, according to a report released Friday showing Berlin was still growing 2.6 per'
